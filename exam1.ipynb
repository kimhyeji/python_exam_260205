# %%
class Employee:
    def work(self):
        print("직원이 일을 합니다.")
        

class Manager(Employee):
    def work(self):
        super().work()
        print("매니저가 팀을 관리합니다.")
        

manager = Manager()
manager.work()

# 출력 결과:
# 직원이 일을 합니다.
# 매니저가 팀을 관리합니다.
# Out:
# 직원이 일을 합니다.
# 매니저가 팀을 관리합니다.
